# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')

# %%
train.head()
# Out:
#    ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  Upper_Age  \
# 0   1        C3         3213            Rented          Individual         36
# 1   2        C5         1117             Owned               Joint         75
# 2   3        C5         3732             Owned          Individual         32
# 3   4       C24         4378             Owned               Joint         52
# 4   5        C8         2190            Rented          Individual         44
#
#    Lower_Age Is_Spouse Health Indicator Holding_Policy_Duration  \
# 0         36        No               X1                     14+
# 1         22        No               X2                     NaN
# 2         32        No              NaN                     1.0
# 3         48        No               X1                     14+
# 4         44        No               X2                     3.0
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response
# ...

# %%
train.shape
# Out:
# (50882, 14)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
missing=train.isnull().sum()
missing=missing[missing>0]
missing.plot.bar()

# %%
test.shape
# Out:
# (21805, 13)

# %%
sns.countplot(train['Response'])
plt.show()

# %%
len(train['City_Code'].unique())
# Out:
# 36

# %%
sns.countplot(train['City_Code'],hue=train['Response'])
plt.show()

# %%
len(train['Region_Code'].unique())
# Out:
# 5316

# %%
len(train['Accomodation_Type'].unique())
# Out:
# 2

# %%
sns.countplot(train['Accomodation_Type'],hue=train['Response'])
plt.show()

# %%
sns.countplot(train['Reco_Insurance_Type'],hue=train['Response'])
plt.show()

# %%
sns.FacetGrid(train, hue='Response',height=5)\
    .map(sns.distplot,'Upper_Age')\
    .add_legend();
plt.title('PDF for Upper_Age')
plt.show();

# %%
sns.FacetGrid(train, hue='Response',height=5)\
    .map(sns.distplot,'Lower_Age')\
    .add_legend();
plt.title('PDF for Lower_Age')
plt.show();

# %%
sns.FacetGrid(train, hue='Response',height=5)\
    .map(sns.distplot,'Region_Code')\
    .add_legend();
plt.title('PDF for Region_Code')
plt.show();

# %%
sns.countplot(train['Is_Spouse'],hue=train['Response'])
plt.show()

# %%
sns.countplot(train['Holding_Policy_Duration'],hue=train['Response'])
plt.show()

# %%
sns.countplot(train['Health Indicator'],hue=train['Response'])
plt.show()

# %%
sns.countplot(train['Holding_Policy_Type'],hue=train['Response'])
plt.show()

# %%
sns.countplot(train['Reco_Policy_Cat'],hue=train['Response'])
plt.show()

# %%
len(train['Reco_Policy_Premium'].unique())
# Out:
# 6977

# %%
sns.FacetGrid(train, hue='Response',height=5)\
    .map(sns.distplot,'Reco_Policy_Premium')\
    .add_legend();
plt.title('PDF for Reco_Policy_Premium')
plt.show();

# %%
train['age_diff']=((train['Upper_Age']-train['Lower_Age'])==0)

# %%
train
# Out:
#           ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 0          1        C3         3213            Rented          Individual
# 1          2        C5         1117             Owned               Joint
# 2          3        C5         3732             Owned          Individual
# 3          4       C24         4378             Owned               Joint
# 4          5        C8         2190            Rented          Individual
# ...      ...       ...          ...               ...                 ...
# 50877  50878        C4          845            Rented          Individual
# 50878  50879        C5         4188            Rented          Individual
# 50879  50880        C1          442            Rented          Individual
# 50880  50881        C1            4             Owned               Joint
# 50881  50882        C3         3866            Rented          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
sns.countplot(train['age_diff'],hue=train['Response'])
plt.show()

# %%
sns.lineplot(x=train['Region_Code'],y=train['Response'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-140-aabf2c91402f> in <module>
# ----> 1 sns.lineplot(x=train['Region_Code'],y=train['Response'])
#
# d:\Anaconda3\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#    1135         ax = plt.gca()
#    1136
# -> 1137     p.plot(ax, kwargs)
#    1138     return ax
#    1139
#
# d:\Anaconda3\lib\site-packages\seaborn\relational.py in plot(self, ax, kws)
#     812                     err = "estimator must be None when specifying units"
#     813                     raise ValueError(err)
# --> 814                 x, y, y_ci = self.aggregate(y, x, units)
#     815             else:
# ...
